# %% [markdown]
# **Importing necessary libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Loading the dataset to the console.**

# %%
telecom = pd.read_csv("telecom_churn.csv")

# %% [markdown]
# **Displaying first five (5) records of the dataset**

# %%
telecom.head()
# Out:
#    Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  CustServCalls  \
# 0      0           128                1         1        2.7              1
# 1      0           107                1         1        3.7              1
# 2      0           137                1         0        0.0              0
# 3      0            84                0         0        0.0              2
# 4      0            75                0         0        0.0              3
#
#    DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 0    265.1       110           89.0        9.87      10.0
# 1    161.6       123           82.0        9.78      13.7
# 2    243.4       114           52.0        6.06      12.2
# 3    299.4        71           57.0        3.10       6.6
# 4    166.7       113           41.0        7.42      10.1

# %% [markdown]
# **Display the list features in the dataset**

# %%
telecom.columns
# Out:
# Index(['Churn', 'AccountWeeks', 'ContractRenewal', 'DataPlan', 'DataUsage',
#        'CustServCalls', 'DayMins', 'DayCalls', 'MonthlyCharge', 'OverageFee',
#        'RoamMins'],
#       dtype='object')

# %% [markdown]
# **Checking the data types of the listed features**

# %%
telecom.dtypes
# Out:
# Churn                int64
# AccountWeeks         int64
# ContractRenewal      int64
# DataPlan             int64
# DataUsage          float64
# CustServCalls        int64
# DayMins            float64
# DayCalls             int64
# MonthlyCharge      float64
# OverageFee         float64
# RoamMins           float64
# dtype: object

# %% [markdown]
# **Checking the size of the dataset: Rows = 3,333 and 11 features.**

# %%
telecom.shape
# Out:
# (3333, 11)

# %% [markdown]
# **Checking to firm the availability of any null cells in the records. No empthy cells detected.**

# %%
telecom.isnull().sum()
# Out:
# Churn              0
# AccountWeeks       0
# ContractRenewal    0
# DataPlan           0
# DataUsage          0
# CustServCalls      0
# DayMins            0
# DayCalls           0
# MonthlyCharge      0
# OverageFee         0
# RoamMins           0
# dtype: int64

# %% [markdown]
# **Confirming the dataset again by displaying few records from the top rows and the bottom rows.**

# %%
telecom
# Out:
#       Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  \
# 0         0           128                1         1       2.70
# 1         0           107                1         1       3.70
# 2         0           137                1         0       0.00
# 3         0            84                0         0       0.00
# 4         0            75                0         0       0.00
# ...     ...           ...              ...       ...        ...
# 3328      0           192                1         1       2.67
# 3329      0            68                1         0       0.34
# 3330      0            28                1         0       0.00
# 3331      0           184                0         0       0.00
# 3332      0            74                1         1       3.70
#
#       CustServCalls  DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 0                 1    265.1       110           89.0        9.87      10.0
# ...

# %% [markdown]
# **The target column is named 'Churn' and needed to be removed and separated the from the dataset, and declaring the remaining features as "X", while Defining the target label ("Churn") as "y"**

# %%
X = telecom.drop('Churn', axis=1)  # Features
y = telecom['Churn']  # Target

# %% [markdown]
# **Checking the dataframe (X) after dropping the target variable**

# %%
X.head()
# Out:
#    AccountWeeks  ContractRenewal  DataPlan  DataUsage  CustServCalls  DayMins  \
# 0           128                1         1        2.7              1    265.1
# 1           107                1         1        3.7              1    161.6
# 2           137                1         0        0.0              0    243.4
# 3            84                0         0        0.0              2    299.4
# 4            75                0         0        0.0              3    166.7
#
#    DayCalls  MonthlyCharge  OverageFee  RoamMins
# 0       110           89.0        9.87      10.0
# 1       123           82.0        9.78      13.7
# 2       114           52.0        6.06      12.2
# 3        71           57.0        3.10       6.6
# 4       113           41.0        7.42      10.1

# %% [markdown]
# **Checking few data from the target variable (y)**

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Churn, dtype: int64

# %% [markdown]
# **Plotting a pairwise scatter plot from the "Matplotlib" library to generate insight of the relationship between the features in the dataset.**

# %%
pd.plotting.scatter_matrix(telecom, c=y, figsize=[10,10], s=150)
plt.show()

# %% [markdown]
# **Importing the model selection from the Sklearn library to engage the train and test set splitting of the dataset**

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Split data into training and test sets: Assigning 25% to test size, 75% to the train size, while maintaing the randon value generationg to be 45**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=45)

# %% [markdown]
# **After, dividing the train and test set, 2,499 (75%) records of the data were randomly assigned to the train set, while 834 (25%) records were assigned to the test set.**

# %%
X_train.shape
# Out:
# (2499, 10)

# %%
X_test.shape
# Out:
# (834, 10)

# %% [markdown]
# **Importing the Decision Tree Classifier, and assign to a variable "teltree"**

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
teltree = DecisionTreeClassifier()

# %%
teltree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# **Evaluate the model: By Using the test set to evaluate the performance of the model.**

# %%
pred = teltree.predict(X_test)

# %% [markdown]
# **Importing the Metrics library to extract the performance of the model**

# %%
from sklearn import metrics

# %% [markdown]
# **Evaluate the model's performance (e.g., accuracy)**

# %%
metrics.accuracy_score(y_test,pred)
# Out:
# 0.9016786570743405

# %%
teltree.score(X_test, y_test)
# Out:
# 0.9016786570743405

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# %% [markdown]
# **Define the feature names from the DataFrame**

# %%
feature_names = X.columns

# %% [markdown]
# **Plotting the decision tree**

# %%
plt.figure(figsize=(20, 10))  # Set the figure size as desired
plot_tree(teltree, filled=True, rounded=True, feature_names=X.columns, class_names=True)
plt.show()

# %% [markdown]
# **The `y_test` is the true labels from your test set**

# %%
conf_matrix = confusion_matrix(y_test,pred)

# %% [markdown]
# **Extracting other metrics to further test the performance of the model**

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
accuracy = accuracy_score(y_test, pred)
precision = precision_score(y_test, pred)
recall = recall_score(y_test, pred)
f1 = f1_score(y_test, pred)
tn, fp, fn, tp = confusion_matrix(y_test, pred).ravel()
specificity = tn / (tn + fp)

# %%
print(f'Accuracy: {accuracy:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall (Sensitivity): {recall:.4f}')
print(f'Specificity: {specificity:.4f}')
print(f'F1-Score: {f1:.4f}')
# Out:
# Accuracy: 0.9017
# Precision: 0.6555
# Recall (Sensitivity): 0.6555
# Specificity: 0.9427
# F1-Score: 0.6555

# %% [markdown]
# **Visualizing the confusion matrix**

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
